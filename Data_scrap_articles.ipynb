# %%
from newsapi import NewsApiClient
import pandas as pd
pd.set_option('display.max_colwidth', 400)

newsapi = NewsApiClient(api_key="c564dae66d524b4c9030e941b6323fad")
# Chosen period : 2020-12-09 - 2020-12-16
all_articles = newsapi.get_everything(q="bitcoin", language="en", from_param='2020-12-09', to='2020-12-16', sort_by="popularity", page_size=100)

# %%
df = pd.DataFrame(all_articles["articles"])
data = pd.DataFrame({"title" : df.title,
                 "description" : df.description,
                    "date" : df.publishedAt})

# %%
data = data.sort_values(by=["date"]).reset_index(drop=True)
data = data.drop_duplicates(subset=['description']).reset_index(drop=True)
data = data.dropna()

# %%
data
# Out:
#                                                                                                                           title  \
# 0                                         COLUMN-Getting mighty crowded - searching for market elbow room: Mike Dolan - Reuters
# 1                                        Column: Getting mighty crowded - searching for market elbow room: Mike Dolan - Reuters
# 2   Bitcoin, Ethereum, Ripple’s XRP, Litecoin And Chainlink In Free Fall After Bitcoin Price Crashes Under $18,000—What’s Next?
# 3                                                                                       The Grumpy Designer Looks Ahead to 2021
# 4                                                                          4 Game-Changing Stocks to Invest $1,000 In Right Now
# ..                                                                                                                          ...
# 81                                                                                  Bitcoin tops $20K for the first time - CNET
# 82                              Jeff Reeves's Strength in Numbers: I admit it — these are my 5 dumbest investment calls of 2020
# 83                                                                                               How I Blew My Bitcoin on Sushi
# 84                                                       Bitcoin at all-time high of $21,300 as institutional investors move in
# 85                                                  Asia stocks firm as U.S. economic support pushes Nasdaq to record - Reuters
#
#                                                                                                                                                                                                                                                           description  \
# 0                                                                       The biggest fear in markets is often of market behaviour itself - and it's enough to scare investors about overcrowded trades next year as an overwhelmingly bullish consensus unnerves many.
# 1                                                                                                                                                                               Column: Getting mighty crowded - searching for market elbow room: Mike Dolan  Reuters
# 2                                                                                                                                                            Bitcoin has fallen sharply over the last 24 hours, moving away from the key $20,000 per bitcoin level...
# 3                                                          Consider this the definitive tongue-in-cheek look at how the new year will impact the web design community.\nThe post The Grumpy Designer Looks Ahead to 2021 appeared first on Speckyboy Design Magazine.
# 4                                                                                                                                                                                                                 These innovative companies can make investors rich.
# ..                                                                                                                                                                                                                                                                ...
# 81                                                                                                                                                                                                                          The cryptocurrency has hit a record high.
# 82                                                                                                                                              Jeff Reeves says he was wrong about COVID-19's impact on the S&P 500, about marijuana stocks, about bitcoin and more.
# 83                                                                                          In 2013, this reporter spent 10 Bitcoin, worth $1,000 at the time, on a dinner for dozens of strangers in San Francisco. The owner of the restaurant wisely held onto it.
# 84  The price of bitcoin has been steadily on the increase as institutional investors are adding it to their portfolios as a hedge against fiat currency devaluation. As of 2:15pm PT the price of a bitcoin on the Coinbase Pro exchange is $21,328. — Read the rest
# 85                                             Asian stocks were set for gains on Thursday as progress toward a long-awaited U.S. stimulus package and a pledge by the Federal Reserve to keep interest rates low helped the Nasdaq benchmark to a fresh record high.
#
#                     date
# 0   2020-12-09T07:00:00Z
# 1   2020-12-09T07:13:00Z
# 2   2020-12-09T08:14:10Z
# 3   2020-12-09T09:17:08Z
# 4   2020-12-09T10:51:00Z
# ..                   ...
# 81  2020-12-16T20:52:00Z
# 82  2020-12-16T21:01:00Z
# 83  2020-12-16T21:58:42Z
# 84  2020-12-16T22:21:43Z
# 85  2020-12-16T23:56:00Z
#
# [85 rows x 3 columns]

# %%
# Clean
import re
import string

def clean_text(text):
    if type(text) == str:
        text = text.lower()
        text = re.sub('\[.*?\]', '', text)
        text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
        text = re.sub('[‘’“”…]', '', text)
        text = re.sub('\n', '', text)
        return text
    return text

clean = lambda x: clean_text(x)

# %%
data_clean = data
data_clean.title = data.title.apply(clean)
data_clean.description = data.description.apply(clean)
data_clean
# Out:
#                                                                                                                   title  \
# 0                                     columngetting mighty crowded  searching for market elbow room mike dolan  reuters
# 1                                    column getting mighty crowded  searching for market elbow room mike dolan  reuters
# 2   bitcoin ethereum ripples xrp litecoin and chainlink in free fall after bitcoin price crashes under 18000—whats next
# 3                                                                               the grumpy designer looks ahead to 2021
# 4                                                                     4 gamechanging stocks to invest 1000 in right now
# ..                                                                                                                  ...
# 81                                                                            bitcoin tops 20k for the first time  cnet
# 82                        jeff reevess strength in numbers i admit it — these are my 5 dumbest investment calls of 2020
# 83                                                                                       how i blew my bitcoin on sushi
# 84                                                  bitcoin at alltime high of 21300 as institutional investors move in
# 85                                             asia stocks firm as us economic support pushes nasdaq to record  reuters
#
#                                                                                                                                                                                                                                                      description  \
# 0                                                                     the biggest fear in markets is often of market behaviour itself  and its enough to scare investors about overcrowded trades next year as an overwhelmingly bullish consensus unnerves many
# 1                                                                                                                                                                             column getting mighty crowded  searching for market elbow room mike dolan  reuters
# 2                                                                                                                                                             bitcoin has fallen sharply over the last 24 hours moving away from the key 20000 per bitcoin level
# 3                                                           consider this the definitive tongueincheek look at how the new year will impact the web design communitythe post the grumpy designer looks ahead to 2021 appeared first on speckyboy design magazine
# 4                                                                                                                                                                                                             these innovative companies can make investors rich
# ..                                                                                                                                                                                                                                                           ...
# 81                                                                                                                                                                                                                      the cryptocurrency has hit a record high
# 82                                                                                                                                               jeff reeves says he was wrong about covid19s impact on the sp 500 about marijuana stocks about bitcoin and more
# 83                                                                                            in 2013 this reporter spent 10 bitcoin worth 1000 at the time on a dinner for dozens of strangers in san francisco the owner of the restaurant wisely held onto it
# 84  the price of bitcoin has been steadily on the increase as institutional investors are adding it to their portfolios as a hedge against fiat currency devaluation as of 215pm pt the price of a bitcoin on the coinbase pro exchange is 21328 — read the rest
# 85                                            asian stocks were set for gains on thursday as progress toward a longawaited us stimulus package and a pledge by the federal reserve to keep interest rates low helped the nasdaq benchmark to a fresh record high
#
#                     date
# 0   2020-12-09T07:00:00Z
# 1   2020-12-09T07:13:00Z
# 2   2020-12-09T08:14:10Z
# 3   2020-12-09T09:17:08Z
# 4   2020-12-09T10:51:00Z
# ..                   ...
# 81  2020-12-16T20:52:00Z
# 82  2020-12-16T21:01:00Z
# 83  2020-12-16T21:58:42Z
# 84  2020-12-16T22:21:43Z
# 85  2020-12-16T23:56:00Z
#
# [85 rows x 3 columns]

# %%
def keep_date_only(date):
    return date[:10]

clean_date = lambda x : keep_date_only(x)

# %%
data_clean.date = data_clean.date.apply(clean_date)

# %%
data_clean.to_pickle("pickle/articles.pkl")
