# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# Extract data history of BTC from alpha vantage API
from alpha_vantage.cryptocurrencies import CryptoCurrencies
key = "DVT0H8E56WGAV95G"
cc = CryptoCurrencies(key=key, output_format='pandas')

data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='EUR')

# %%
data['4b. close (USD)'].plot()
plt.tight_layout()
plt.title('Daily close value for bitcoin (BTC)')
plt.grid()
plt.show()

# %%
data
# Out:
#             1a. open (EUR)  1b. open (USD)  2a. high (EUR)  2b. high (USD)  \
# date
# 2020-12-17    17490.859296        21335.52    17611.640430        21482.85
# 2020-12-16    15925.787314        19426.43    17674.888000        21560.00
# 2020-12-15    15800.571062        19273.69    16043.486000        19570.00
# 2020-12-14    15719.656802        19174.99    15862.310200        19349.00
# 2020-12-13    15419.364062        18808.69    15913.137800        19411.00
# ...                    ...             ...             ...             ...
# 2018-03-28     6390.759098         7795.51     6647.758200         8109.00
# 2018-03-27     6668.433556         8134.22     6735.427612         8215.94
# 2018-03-26     6943.820772         8470.14     6980.506822         8514.89
# 2018-03-25     6993.918750         8531.25     7107.543030         8669.85
# 2018-03-24     7294.613192         8898.04     7378.159010         8999.95
#
# ...

# %%
import datetime

d1 = datetime.datetime(2020, 12, 15)
d2 = datetime.datetime(2020, 12, 9)

data_period = data.drop(data[data.index > d1].index, axis=0)
data_period = data_period.drop(data_period[data_period.index < d2]. index, axis=0)
data_period
# Out:
#             1a. open (EUR)  1b. open (USD)  2a. high (EUR)  2b. high (USD)  \
# date
# 2020-12-15    15800.571062        19273.69    16043.486000        19570.00
# 2020-12-14    15719.656802        19174.99    15862.310200        19349.00
# 2020-12-13    15419.364062        18808.69    15913.137800        19411.00
# 2020-12-12    14786.347294        18036.53    15534.111468        18948.66
# 2020-12-11    14965.293238        18254.81    14996.380054        18292.73
# 2020-12-10    15200.149542        18541.29    15213.290936        18557.32
# 2020-12-09    15022.105378        18324.11    15280.719486        18639.57
#
#             3a. low (EUR)  3b. low (USD)  4a. close (EUR)  4b. close (USD)  \
# date
# 2020-12-15   15617.190000       19050.00     15925.787314         19426.43
# 2020-12-14   15576.200000       19000.00     15800.120172         19273.14
# 2020-12-13   15339.376176       18711.12     15719.656802         19174.99
# ...

# %%
plt.figure()
plt.title('Daily close value for bitcoin (BTC)')
data_period['4b. close (USD)'].plot(color="red", label="BTC")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
data_period.to_pickle("pickle/stock.pkl")
